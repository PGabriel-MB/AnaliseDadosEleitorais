# %%
import pandas as pd
import numpy as np
low_memory=False
# %matplotlib inline

# Dados dos candidatos a VEREADORES
# de São José dos Campos - SP 
# nas eleições de 2000

filename_vereadores = 'eleicoes-brasil-2000_vereadores.csv'
df_vereadores = pd.read_csv(filename_vereadores, encoding='utf-8', sep=',')
df_vereadores.sample(10)
# Out:
#       ano_eleicao sigla_uf       nome_municipio descricao_cargo  num_turno  \
# 706          2000       SP  SAO JOSE DOS CAMPOS        VEREADOR          1
# 581          2000       SP  SAO JOSE DOS CAMPOS        VEREADOR          1
# 514          2000       SP  SAO JOSE DOS CAMPOS        VEREADOR          1
# 1224         2000       SP  SAO JOSE DOS CAMPOS        VEREADOR          1
# 1299         2000       SP  SAO JOSE DOS CAMPOS        VEREADOR          1
# 146          2000       SP  SAO JOSE DOS CAMPOS        VEREADOR          1
# 986          2000       SP  SAO JOSE DOS CAMPOS        VEREADOR          1
# 336          2000       SP  SAO JOSE DOS CAMPOS        VEREADOR          1
# 945          2000       SP  SAO JOSE DOS CAMPOS        VEREADOR          1
# 574          2000       SP  SAO JOSE DOS CAMPOS        VEREADOR          1
#
#       numero_zona sigla_partido                             nome_candidato  \
# 706           127           PPB  MARIA IRMA VASCONCELOS DE MELO DOS SANTOS
# 581           412           PTN                        LEILA MARIA DE LIMA
# 514           411            PT                WALTER FERNANDES CANDELARIO
# 1224          412           PHS            JOSÉ FRANCISCO ALVES DOS SANTOS
# 1299          411          PMDB                 LUIZ CARLOS BOSCO DA SILVA
# 146           411           PTB                               SANTOS NEVES
# 986           411          PMDB                   VERA LUCIA DA CRUZ PAULA
# 336           411           PPS                         IBERE BARBOSA LIMA
# 945           411            PV       SANDRA MARIA DO NASCIMENTO RODRIGUES
# 574           412           PPS                MARIA APARECIDA DE OLIVEIRA
#
#                  nome_urna_candidato  numero_cand  desc_sit_cand_superior  \
# 706   MARIA IRMA VASCONCELOS DE M. S        11607                     NaN
# 581                            LEILA        19601                     NaN
# 514                            SIENA        13350                     NaN
# 1224                 FRANCISCO ALVES        31660                     NaN
# 1299            ROBERTO CARLOS COVER        15524                     NaN
# 146                     SANTOS NEVES        14676                     NaN
# 986                 VERA DO POSTINHO        15513                     NaN
# 336                            IBERE        23888                     NaN
# 945                 SANDRA RODRIGUES        43200                     NaN
# 574                   CIDA DA CAMARA        23691                     NaN
#
#      desc_sit_candidato desc_sit_cand_tot  total_votos
# 706            DEFERIDO          SUPLENTE           47
# 581            DEFERIDO          SUPLENTE           71
# 514            DEFERIDO          SUPLENTE           84
# 1224           DEFERIDO          SUPLENTE           10
# 1299           DEFERIDO          SUPLENTE            7
# 146            DEFERIDO            ELEITO          381
# 986            DEFERIDO          SUPLENTE           21
# 336            DEFERIDO          SUPLENTE          153
# 945            DEFERIDO          SUPLENTE           24
# 574            DEFERIDO          SUPLENTE           72

# %%
data = {
    'Sigla do Partido': df_vereadores['sigla_partido'],
    'Nome do Candidato': df_vereadores['nome_candidato'],
    'Todal de Votos': df_vereadores['total_votos'],
    'Resultado': df_vereadores['desc_sit_cand_tot']
}

new_df_vereadores = pd.DataFrame(data=data)
new_df_vereadores.groupby('Sigla do Partido').sum('Total de Votos')
# Out:
#                   Todal de Votos
# Sigla do Partido
# PAN                          495
# PC do B                     1024
# PDT                         5488
# PFL                        33301
# PHS                        15796
# PL                          8719
# PMDB                       15192
# PMN                         1983
# PPB                        12244
# PPS                        13500
# PSB                        22861
# PSDB                       33550
# PST                          293
# PSTU                        3170
# PT                         28509
# PTB                        24797
# PTN                         2162
# PV                          1841

# %%
new_df_vereadores.groupby('Sigla do Partido').sum('Total de Votos').plot(
    kind='barh',
    title="Número de votos por Partido"
)
# Out:
# <AxesSubplot:title={'center':'Número de votos por Partido'}, ylabel='Sigla do Partido'>

# %%
data = {
    'Nome do Candidato': df_vereadores['nome_candidato'],
    'Todal de Votos': df_vereadores['total_votos'],
    'Resultado': df_vereadores['desc_sit_cand_tot']
}

new_df_vereadores = pd.DataFrame(data=data)
new_df_vereadores.groupby('Resultado').sum('Total de Votos').plot(
    kind='bar',
    title="Número de votos por Candidato a VERADORES"
)
# Out:
# <AxesSubplot:title={'center':'Número de votos por Candidato a VERADORES'}, xlabel='Resultado'>
